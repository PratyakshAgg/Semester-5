# %% [markdown]
# ### Question - 1 Use the weather dataset to implement the decision tree. Try different available parameters of the inbuilt method.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OrdinalEncoder
from sklearn import tree

# %%
data = pd.read_csv("weather.csv")
data
# Out:
#      Outlook  Temp Humidity  Windy  Play
# 0      rainy   hot     high      0     0
# 1      rainy   hot     high      1     0
# 2   overcast   hot     high      0     1
# 3      sunny  mild     high      0     1
# 4      sunny  cool   normal      0     1
# 5      sunny  cool   normal      1     0
# 6   overcast  cool   normal      1     1
# 7      rainy  mild     high      0     0
# 8      rainy  cool   normal      0     1
# 9      sunny  mild   normal      0     1
# 10     rainy  mild   normal      1     1
# 11  overcast  mild     high      1     1
# 12  overcast   hot   normal      0     1
# 13     sunny  mild     high      1     0

# %%
enc = OrdinalEncoder()
data[["Outlook","Temp", "Humidity"]] = enc.fit_transform(data[["Outlook","Temp", "Humidity"]])
data
# Out:
#     Outlook  Temp  Humidity  Windy  Play
# 0       1.0   1.0       0.0      0     0
# 1       1.0   1.0       0.0      1     0
# 2       0.0   1.0       0.0      0     1
# 3       2.0   2.0       0.0      0     1
# 4       2.0   0.0       1.0      0     1
# 5       2.0   0.0       1.0      1     0
# 6       0.0   0.0       1.0      1     1
# 7       1.0   2.0       0.0      0     0
# 8       1.0   0.0       1.0      0     1
# 9       2.0   2.0       1.0      0     1
# 10      1.0   2.0       1.0      1     1
# 11      0.0   2.0       0.0      1     1
# 12      0.0   1.0       1.0      0     1
# 13      2.0   2.0       0.0      1     0

# %%
X = data.values[:, 0:4]
y = data.values[:, 4]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)

# %%
entr = DecisionTreeClassifier(criterion="entropy", random_state = 100, max_depth = 3)
entr.fit(X_train, y_train)
entr
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=100)

# %%
y_pred_en = entr.predict(X_test)
y_pred_en
# Out:
# array([1., 1., 1., 0., 1.])

# %%
print(("Accuracy is"), accuracy_score(y_test, y_pred_en)*100)
# Out:
# Accuracy is 80.0
